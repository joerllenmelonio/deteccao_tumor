# %%
# !nvidia-smi
# Out:
# Mon Jul 28 14:43:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import warnings
import cv2
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import normalize
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import Binarizer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
import time

# %%
from google.colab import drive
drive.mount('/content/driv')
# Out:
# Drive already mounted at /content/driv; to attempt to forcibly remount, call drive.mount("/content/driv", force_remount=True).

# %%
timeinicial= time.time()
path ='/content/driv/MyDrive/deteccao_tumores/dataset_cerebros/nao'
path2 ='/content/driv/MyDrive/deteccao_tumores/dataset_cerebros/sim'
arquivos=[os.path.join(path,f) for f in sorted(os.listdir(path))]
arquivos2=[os.path.join(path2,i) for i in sorted(os.listdir(path2))]


largura, altura=299,299
dataset= [] #informações sobre os pixels
label = [] #tipo de classe

for caminho in arquivos:

  imagem= cv2.imread(caminho)
  imagem = cv2.resize(imagem,(largura, altura)) #redimencionando todas as imagens
  #imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY) #transformando as imagens para escala de cinza
  #cv2_imshow(imagem)

  dataset.append(np.array(imagem))
  label.append(0)# adiciona a classe não tem tumor


for caminho2 in arquivos2:

  imagem= cv2.imread(caminho2)
  imagem = cv2.resize(imagem,(largura, altura))#redimencionando todas as imagens
  #imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY) #transformando as imagens para escala de cinza
  #cv2_imshow(imagem)

  dataset.append(np.array(imagem))
  label.append(1)# adiciona classe com tumor


dataset=np.array(dataset)# informação dos pixels
label=np.array(label) # informação das classe
timefinal= time.time()
print(f"duração: {timefinal-timeinicial} segundos")
# Out:
# duração: 17.096438884735107 segundos

# %%
from sklearn.model_selection import train_test_split
# Base de treinamento e teste
x_train, x_test, y_train, y_test=train_test_split(dataset, label, test_size=0.2, random_state=0, shuffle= True)
x_train=normalize(x_train,axis=1)
x_test=normalize(x_test,axis=1)

# %%
# Modelo ResNet50

base_model =  tf.keras.applications.ResNet50(include_top= False, weights='imagenet', input_shape=(299, 299, 3), name="resnet50")
base_model.trainable = False  # Transfer learning: congela base

# adiciona camada para output
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.3)(x)
output = Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(inputs=base_model.input, outputs=output)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 305, 305,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 150, 150,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 150, 150,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 150, 150,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 152, 152,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 75, 75,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 75, 75,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 75, 75,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 75, 75,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 75, 75,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 75, 75,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 75, 75,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 75, 75,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 75, 75,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 75, 75,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 75, 75,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 75, 75,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 75, 75,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 75, 75,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 75, 75,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 75, 75,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 75, 75,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 75, 75,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 75, 75,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 75, 75,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 75, 75,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 38, 38,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 38, 38,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 38, 38,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 38, 38,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 38, 38,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 38, 38,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 38, 38,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 38, 38,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 38, 38,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 38, 38,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 38, 38,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 38, 38,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 38, 38,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 38, 38,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 38, 38,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 38, 38,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 38, 38,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 38, 38,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 38, 38,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 38, 38,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 38, 38,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 38, 38,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 38, 38,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 38, 38,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 38, 38,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 38, 38,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 19, 19,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 19, 19,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 19, 19,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 19, 19,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 19, 19,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 19, 19,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 19, 19,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 19, 19,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 19, 19,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 19, 19,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 19, 19,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 19, 19,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 19, 19,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 19, 19,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 19, 19,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 19, 19,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 19, 19,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 19, 19,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 19, 19,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 19, 19,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 19, 19,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 19, 19,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 19, 19,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 19, 19,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 19, 19,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 19, 19,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 10, 10,    │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 10, 10,    │          0 │ conv5_block1_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 10, 10,    │          0 │ conv5_block1_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 10, 10,    │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 10, 10,    │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 10, 10,    │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 10, 10,    │          0 │ conv5_block2_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 10, 10,    │          0 │ conv5_block2_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 10, 10,    │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 10, 10,    │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 10, 10,    │          0 │ conv5_block3_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 10, 10,    │          0 │ conv5_block3_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 10, 10,    │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 10, 10,    │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,112,513 (91.98 MB)
#  Trainable params: 524,801 (2.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
tempo_inicial=time.time()
# adam = keras.optimizers.Adam(learning_rate=0.01)
# taxa de aprendizado padrão da SGD: 0.01
# otimizador SGD produz maior acurária caso comparado ao Adam
# treinar apenas camadas adicionadas
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),optimizer=keras.optimizers.SGD(learning_rate=0.001),metrics=['accuracy'])
history=model.fit(x_train,y_train,batch_size=16,epochs=50, validation_data=(x_test,y_test)) #batchsize siginifica que vamos enviar 16 em 16 imagens para a rede neural, sem misturar as imagens enviando com a ordem que está n
tempo_final=time.time()

tempo_final-tempo_inicial
# Out:
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 35s 210ms/step - accuracy: 0.6244 - loss: 0.6686 - val_accuracy: 0.7103 - val_loss: 0.6016
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - accuracy: 0.6779 - loss: 0.6516 - val_accuracy: 0.7103 - val_loss: 0.6113
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - accuracy: 0.6672 - loss: 0.6603 - val_accuracy: 0.7103 - val_loss: 0.6219
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - accuracy: 0.6600 - loss: 0.6517 - val_accuracy: 0.7103 - val_loss: 0.6022
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - accuracy: 0.6849 - loss: 0.6426 - val_accuracy: 0.7103 - val_loss: 0.6203
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6847 - loss: 0.6330 - val_accuracy: 0.7103 - val_loss: 0.6063
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - accuracy: 0.6850 - loss: 0.6325 - val_accuracy: 0.7103 - val_loss: 0.6013
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - accuracy: 0.6722 - loss: 0.6529 - val_accuracy: 0.7103 - val_loss: 0.6013
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 100ms/step - accuracy: 0.6828 - loss: 0.6357 - val_accuracy: 0.7103 - val_loss: 0.6037
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6637 - loss: 0.6435 - val_accuracy: 0.7103 - val_loss: 0.6065
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - accuracy: 0.6823 - loss: 0.6332 - val_accuracy: 0.7103 - val_loss: 0.6013
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - accuracy: 0.6890 - loss: 0.6284 - val_accuracy: 0.7103 - val_loss: 0.6060
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.7093 - loss: 0.6122 - val_accuracy: 0.7103 - val_loss: 0.6067
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6823 - loss: 0.6313 - val_accuracy: 0.7103 - val_loss: 0.6030
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6936 - loss: 0.6249 - val_accuracy: 0.7103 - val_loss: 0.6020
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6992 - loss: 0.6136 - val_accuracy: 0.7103 - val_loss: 0.6087
# Epoch 17/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.7036 - loss: 0.6122 - val_accuracy: 0.7103 - val_loss: 0.6021
# Epoch 18/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6881 - loss: 0.6246 - val_accuracy: 0.7103 - val_loss: 0.6049
# Epoch 19/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6842 - loss: 0.6273 - val_accuracy: 0.7103 - val_loss: 0.6018
# Epoch 20/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6936 - loss: 0.6177 - val_accuracy: 0.7103 - val_loss: 0.6048
# Epoch 21/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6883 - loss: 0.6245 - val_accuracy: 0.7103 - val_loss: 0.6044
# Epoch 22/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6939 - loss: 0.6197 - val_accuracy: 0.7103 - val_loss: 0.6098
# Epoch 23/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6660 - loss: 0.6423 - val_accuracy: 0.7103 - val_loss: 0.6028
# Epoch 24/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6881 - loss: 0.6239 - val_accuracy: 0.7103 - val_loss: 0.6013
# Epoch 25/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6947 - loss: 0.6170 - val_accuracy: 0.7103 - val_loss: 0.6094
# Epoch 26/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6805 - loss: 0.6288 - val_accuracy: 0.7103 - val_loss: 0.6042
# Epoch 27/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6627 - loss: 0.6464 - val_accuracy: 0.7103 - val_loss: 0.6013
# Epoch 28/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6854 - loss: 0.6236 - val_accuracy: 0.7103 - val_loss: 0.6015
# Epoch 29/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6752 - loss: 0.6304 - val_accuracy: 0.7103 - val_loss: 0.6015
# Epoch 30/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6841 - loss: 0.6236 - val_accuracy: 0.7103 - val_loss: 0.6048
# Epoch 31/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6662 - loss: 0.6383 - val_accuracy: 0.7103 - val_loss: 0.6028
# Epoch 32/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6983 - loss: 0.6128 - val_accuracy: 0.7103 - val_loss: 0.6041
# Epoch 33/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6620 - loss: 0.6455 - val_accuracy: 0.7103 - val_loss: 0.6010
# Epoch 34/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6668 - loss: 0.6435 - val_accuracy: 0.7103 - val_loss: 0.6052
# Epoch 35/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6679 - loss: 0.6392 - val_accuracy: 0.7103 - val_loss: 0.6023
# Epoch 36/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6968 - loss: 0.6140 - val_accuracy: 0.7103 - val_loss: 0.6053
# Epoch 37/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6890 - loss: 0.6228 - val_accuracy: 0.7103 - val_loss: 0.6059
# Epoch 38/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6714 - loss: 0.6376 - val_accuracy: 0.7103 - val_loss: 0.6029
# Epoch 39/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6901 - loss: 0.6222 - val_accuracy: 0.7103 - val_loss: 0.6042
# Epoch 40/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.7114 - loss: 0.6020 - val_accuracy: 0.7103 - val_loss: 0.6074
# Epoch 41/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6850 - loss: 0.6274 - val_accuracy: 0.7103 - val_loss: 0.6039
# Epoch 42/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.7006 - loss: 0.6110 - val_accuracy: 0.7103 - val_loss: 0.6033
# Epoch 43/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6720 - loss: 0.6345 - val_accuracy: 0.7103 - val_loss: 0.6027
# Epoch 44/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6784 - loss: 0.6235 - val_accuracy: 0.7103 - val_loss: 0.6018
# Epoch 45/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.7045 - loss: 0.6091 - val_accuracy: 0.7103 - val_loss: 0.6042
# Epoch 46/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6918 - loss: 0.6196 - val_accuracy: 0.7103 - val_loss: 0.6049
# Epoch 47/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6826 - loss: 0.6265 - val_accuracy: 0.7103 - val_loss: 0.6024
# Epoch 48/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6739 - loss: 0.6311 - val_accuracy: 0.7103 - val_loss: 0.6021
# Epoch 49/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6948 - loss: 0.6169 - val_accuracy: 0.7103 - val_loss: 0.6038
# Epoch 50/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.6964 - loss: 0.6141 - val_accuracy: 0.7103 - val_loss: 0.6051
# 580.5914053916931

# %%
# realizando fine tuning
tempo_inicial=time.time()
base_model.trainable = True # descongela modelo
model.summary()

print("Número de camadas no modelo base: ", len(base_model.layers))
# inicia fine tune a partir da camada 50
fine_tune_at = 100

# congela todas as camadas até chegar na camada de `fine_tune_at`
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

model.compile(loss=tf.keras.losses.BinaryCrossentropy(),optimizer=keras.optimizers.SGD(learning_rate=0.00001),metrics=['accuracy'])
history=model.fit(x_train,y_train,batch_size=16,epochs=120, initial_epoch=len(history.epoch), validation_data=(x_test,y_test)) #batchsize siginifica que vamos enviar 16 em 16 imagens para a rede neural, sem misturar as imagens enviando com a ordem que está n
tempo_final=time.time()

tempo_final-tempo_inicial
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 305, 305,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 150, 150,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 150, 150,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 150, 150,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 152, 152,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 75, 75,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 75, 75,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 75, 75,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 75, 75,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 75, 75,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 75, 75,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 75, 75,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 75, 75,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 75, 75,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 75, 75,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 75, 75,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 75, 75,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 75, 75,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 75, 75,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 75, 75,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 75, 75,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 75, 75,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 75, 75,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 75, 75,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 75, 75,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 75, 75,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 75, 75,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 75, 75,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 75, 75,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 75, 75,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 38, 38,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 38, 38,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 38, 38,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 38, 38,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 38, 38,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 38, 38,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 38, 38,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 38, 38,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 38, 38,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 38, 38,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 38, 38,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 38, 38,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 38, 38,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 38, 38,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 38, 38,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 38, 38,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 38, 38,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 38, 38,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 38, 38,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 38, 38,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 38, 38,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 38, 38,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 38, 38,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 38, 38,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 38, 38,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 38, 38,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 38, 38,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 38, 38,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 38, 38,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 38, 38,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 19, 19,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 19, 19,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 19, 19,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 19, 19,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 19, 19,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 19, 19,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 19, 19,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 19, 19,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 19, 19,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 19, 19,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 19, 19,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 19, 19,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 19, 19,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 19, 19,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 19, 19,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 19, 19,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 19, 19,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 19, 19,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 19, 19,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 19, 19,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 19, 19,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 19, 19,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 19, 19,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 19, 19,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 19, 19,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 19, 19,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 19, 19,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 19, 19,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 19, 19,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 19, 19,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 19, 19,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 10, 10,    │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 10, 10,    │          0 │ conv5_block1_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 10, 10,    │          0 │ conv5_block1_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 10, 10,    │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 10, 10,    │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 10, 10,    │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 10, 10,    │          0 │ conv5_block2_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 10, 10,    │          0 │ conv5_block2_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 10, 10,    │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 10, 10,    │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 10, 10,    │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 10, 10,    │          0 │ conv5_block3_1_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 10, 10,    │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 10, 10,    │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 10, 10,    │          0 │ conv5_block3_2_b… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 10, 10,    │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 10, 10,    │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 10, 10,    │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 10, 10,    │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,112,515 (91.98 MB)
#  Trainable params: 24,059,393 (91.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)
#  Optimizer params: 2 (12.00 B)
# Número de camadas no modelo base:  175
# Epoch 51/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 49s 289ms/step - accuracy: 0.6841 - loss: 0.6216 - val_accuracy: 0.7103 - val_loss: 0.6663
# Epoch 52/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.6971 - loss: 0.5986 - val_accuracy: 0.7103 - val_loss: 0.6199
# Epoch 53/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 164ms/step - accuracy: 0.6838 - loss: 0.5901 - val_accuracy: 0.7103 - val_loss: 0.6326
# Epoch 54/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 161ms/step - accuracy: 0.6978 - loss: 0.5743 - val_accuracy: 0.7103 - val_loss: 0.5931
# Epoch 55/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 17s 160ms/step - accuracy: 0.6901 - loss: 0.5762 - val_accuracy: 0.7103 - val_loss: 0.5540
# Epoch 56/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.6860 - loss: 0.5588 - val_accuracy: 0.7103 - val_loss: 0.5348
# Epoch 57/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 163ms/step - accuracy: 0.6920 - loss: 0.5620 - val_accuracy: 0.7241 - val_loss: 0.5335
# Epoch 58/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.6945 - loss: 0.5573 - val_accuracy: 0.7218 - val_loss: 0.5188
# Epoch 59/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7160 - loss: 0.5386 - val_accuracy: 0.7471 - val_loss: 0.5151
# Epoch 60/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7004 - loss: 0.5500 - val_accuracy: 0.7379 - val_loss: 0.5059
# Epoch 61/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7154 - loss: 0.5412 - val_accuracy: 0.7448 - val_loss: 0.5045
# Epoch 62/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7147 - loss: 0.5332 - val_accuracy: 0.7241 - val_loss: 0.5020
# Epoch 63/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7127 - loss: 0.5321 - val_accuracy: 0.7425 - val_loss: 0.4976
# Epoch 64/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7042 - loss: 0.5394 - val_accuracy: 0.7379 - val_loss: 0.4926
# Epoch 65/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7266 - loss: 0.5282 - val_accuracy: 0.7540 - val_loss: 0.5009
# Epoch 66/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7167 - loss: 0.5263 - val_accuracy: 0.7356 - val_loss: 0.4892
# Epoch 67/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7507 - loss: 0.5039 - val_accuracy: 0.7609 - val_loss: 0.4845
# Epoch 68/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7322 - loss: 0.5281 - val_accuracy: 0.7609 - val_loss: 0.4826
# Epoch 69/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7123 - loss: 0.5290 - val_accuracy: 0.7540 - val_loss: 0.4756
# Epoch 70/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7453 - loss: 0.4985 - val_accuracy: 0.7701 - val_loss: 0.4786
# Epoch 71/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7349 - loss: 0.5022 - val_accuracy: 0.7632 - val_loss: 0.4812
# Epoch 72/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7344 - loss: 0.5038 - val_accuracy: 0.7494 - val_loss: 0.4758
# Epoch 73/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7269 - loss: 0.5128 - val_accuracy: 0.7793 - val_loss: 0.4808
# Epoch 74/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7481 - loss: 0.5055 - val_accuracy: 0.7103 - val_loss: 0.5039
# Epoch 75/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7445 - loss: 0.5011 - val_accuracy: 0.7149 - val_loss: 0.5852
# Epoch 76/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7302 - loss: 0.5023 - val_accuracy: 0.7195 - val_loss: 0.4936
# Epoch 77/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7635 - loss: 0.4842 - val_accuracy: 0.7517 - val_loss: 0.4876
# Epoch 78/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7682 - loss: 0.4910 - val_accuracy: 0.7632 - val_loss: 0.4848
# Epoch 79/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7558 - loss: 0.4918 - val_accuracy: 0.7862 - val_loss: 0.4570
# Epoch 80/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7881 - loss: 0.4651 - val_accuracy: 0.7908 - val_loss: 0.4519
# Epoch 81/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7581 - loss: 0.5036 - val_accuracy: 0.7908 - val_loss: 0.4503
# Epoch 82/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7706 - loss: 0.4867 - val_accuracy: 0.7862 - val_loss: 0.4809
# Epoch 83/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7424 - loss: 0.4976 - val_accuracy: 0.7770 - val_loss: 0.4466
# Epoch 84/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7798 - loss: 0.4723 - val_accuracy: 0.7103 - val_loss: 0.5282
# Epoch 85/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7405 - loss: 0.5054 - val_accuracy: 0.7816 - val_loss: 0.4900
# Epoch 86/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7790 - loss: 0.4643 - val_accuracy: 0.7816 - val_loss: 0.4445
# Epoch 87/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7503 - loss: 0.4941 - val_accuracy: 0.7494 - val_loss: 0.4578
# Epoch 88/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7866 - loss: 0.4613 - val_accuracy: 0.8184 - val_loss: 0.4444
# Epoch 89/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7748 - loss: 0.4773 - val_accuracy: 0.7724 - val_loss: 0.4961
# Epoch 90/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7678 - loss: 0.4673 - val_accuracy: 0.7885 - val_loss: 0.4496
# Epoch 91/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7712 - loss: 0.4647 - val_accuracy: 0.7770 - val_loss: 0.5149
# Epoch 92/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7725 - loss: 0.4771 - val_accuracy: 0.8069 - val_loss: 0.4615
# Epoch 93/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7928 - loss: 0.4546 - val_accuracy: 0.7241 - val_loss: 0.5469
# Epoch 94/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7873 - loss: 0.4553 - val_accuracy: 0.7931 - val_loss: 0.4743
# Epoch 95/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7771 - loss: 0.4546 - val_accuracy: 0.8230 - val_loss: 0.4349
# Epoch 96/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7869 - loss: 0.4622 - val_accuracy: 0.8253 - val_loss: 0.4277
# Epoch 97/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7993 - loss: 0.4617 - val_accuracy: 0.7356 - val_loss: 0.4630
# Epoch 98/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7946 - loss: 0.4615 - val_accuracy: 0.7448 - val_loss: 0.4579
# Epoch 99/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8065 - loss: 0.4522 - val_accuracy: 0.7218 - val_loss: 0.4850
# Epoch 100/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7511 - loss: 0.4779 - val_accuracy: 0.7356 - val_loss: 0.4694
# Epoch 101/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8005 - loss: 0.4461 - val_accuracy: 0.7379 - val_loss: 0.4621
# Epoch 102/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7949 - loss: 0.4743 - val_accuracy: 0.7425 - val_loss: 0.4601
# Epoch 103/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8062 - loss: 0.4523 - val_accuracy: 0.7977 - val_loss: 0.4608
# Epoch 104/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8037 - loss: 0.4548 - val_accuracy: 0.7977 - val_loss: 0.4403
# Epoch 105/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8053 - loss: 0.4519 - val_accuracy: 0.8092 - val_loss: 0.4633
# Epoch 106/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8068 - loss: 0.4596 - val_accuracy: 0.7425 - val_loss: 0.4517
# Epoch 107/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7990 - loss: 0.4437 - val_accuracy: 0.7678 - val_loss: 0.4407
# Epoch 108/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8184 - loss: 0.4394 - val_accuracy: 0.7931 - val_loss: 0.4813
# Epoch 109/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7864 - loss: 0.4487 - val_accuracy: 0.8299 - val_loss: 0.4605
# Epoch 110/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7974 - loss: 0.4438 - val_accuracy: 0.7977 - val_loss: 0.4483
# Epoch 111/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7818 - loss: 0.4702 - val_accuracy: 0.7379 - val_loss: 0.4489
# Epoch 112/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8049 - loss: 0.4409 - val_accuracy: 0.7655 - val_loss: 0.4253
# Epoch 113/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8108 - loss: 0.4502 - val_accuracy: 0.7931 - val_loss: 0.4518
# Epoch 114/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8214 - loss: 0.4324 - val_accuracy: 0.8368 - val_loss: 0.3935
# Epoch 115/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8224 - loss: 0.4335 - val_accuracy: 0.7908 - val_loss: 0.4141
# Epoch 116/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8109 - loss: 0.4300 - val_accuracy: 0.8069 - val_loss: 0.4553
# Epoch 117/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8250 - loss: 0.4268 - val_accuracy: 0.8207 - val_loss: 0.4099
# Epoch 118/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.7988 - loss: 0.4485 - val_accuracy: 0.7609 - val_loss: 0.4270
# Epoch 119/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8171 - loss: 0.4229 - val_accuracy: 0.8368 - val_loss: 0.3942
# Epoch 120/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.8053 - loss: 0.4283 - val_accuracy: 0.7494 - val_loss: 0.5180
# 1272.4331986904144

# %%
print(f"o codigo demorou {int(tempo_final-tempo_inicial)} segundos")
# Out:
# o codigo demorou 1272 segundos

# %%
from sklearn.preprocessing import Binarizer
# predição para obter acurácia do modelo
score = model.evaluate(x_test, y_test)
prediction = model.predict(x_test)
#############
binarizer = Binarizer(threshold=0.50).fit(prediction)
binary = binarizer.transform(prediction)
#############
y_test = y_test
y_pred = binary
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 508ms/step - accuracy: 0.7394 - loss: 0.5271
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 407ms/step

# %%
print("Resultados da Classificação = ")
print(classification_report(y_test,y_pred))
# Out:
# Resultados da Classificação =
#               precision    recall  f1-score   support
#
#            0       0.95      0.68      0.79       309
#            1       0.54      0.92      0.68       126
#
#     accuracy                           0.75       435
#    macro avg       0.75      0.80      0.74       435
# weighted avg       0.83      0.75      0.76       435

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the loss and accuracy curve
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='melhor época = '+ str(index_loss+1 +start_epoch)
    vc_label='melhor época = '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Perda de Treinamento')
    axes[0].plot(Epochs,vloss,'g',label='Perda de Validação' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Treinamento e validação das perdas')
    axes[0].set_xlabel('Épocas')
    axes[0].set_ylabel('Perda')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Acurácia de Treinamento')
    axes[1].plot (Epochs,vacc,'g',label= 'Acurácia de Validação')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Treinamento e validação da acurácia')
    axes[1].set_xlabel('Épocas')
    axes[1].set_ylabel('Acurácia')
    axes[1].legend()
    plt.tight_layout

    plt.show()

tr_plot(history,0)
plt.savefig('history.png')
model.save('/content/driv/MyDrive/deteccao_tumores/modelos/modelo_resnet50.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
caminho_modelo = '/content/driv/MyDrive/deteccao_tumores/modelos/modelo_resnet50.h5'
modelo = tf.keras.models.load_model(caminho_modelo)
largura, altura=299,299
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def criar_mosaico(titulo, cor_sim, cor_nao, arquivos, modelo, rows, cols):
    """
    Cria um mosaico com imagens classificadas e seus respectivos resulktados.
    """
    imagens = []
    for arquivo in arquivos:
        img = cv2.imread(arquivo)
        if img is not None:
            img = cv2.resize(img, (largura, altura))
            imagens.append(img)
        else:
            print(f"Nao foi possivel carregar imagem {arquivo}")

    if not imagens:
        print("Nenhuma imagem carregada.")
        return

    # Define tamanho do mosaico
    img_h, img_w, _ = imagens[0].shape
    texto_h = 40  # Espaço para texto
    mosaico_h = (img_h + texto_h) * rows
    mosaico_w = img_w * cols
    mosaico = np.zeros((mosaico_h, mosaico_w, 3), dtype=np.uint8)
    mosaico.fill(255)


    # Classificação das imagens de RM
    imagem_index = 0
    for r in range(rows):
        for c in range(cols):
            if imagem_index < len(imagens):
                # Place the image
                mosaico[r * (img_h + texto_h):r * (img_h + texto_h) + img_h, c * img_w:(c + 1) * img_w] = imagens[imagem_index]

                # Classificação
                print(f"\Classificando imagem: {arquivos[imagem_index]}")
                # Normaliza imagem e realiza predicao
                img_to_predict = cv2.imread(arquivos[imagem_index])
                img_to_predict = cv2.resize(img_to_predict, (largura, altura))
                img_to_predict = cv2.cvtColor(img_to_predict, cv2.COLOR_BGR2RGB)
                img_to_predict = normalize(img_to_predict, axis=1)
                img_to_predict = img_to_predict.reshape(1, largura, altura, 3)
                predicao = modelo.predict(img_to_predict)
                probabilidade = predicao[0][0] * 100
                # Presença de tunmor: precisao acima de 50%
                if predicao[0][0] > 0.5:
                    texto_img_classificada = f"Com Tumor: {probabilidade:.2f}%"
                    cor = cor_sim # Cor definida para respostas certas/erradas
                    # print(f"Diagnóstico: Tumor Detectado (Probabilidade: {probabilidade:.2f}%)")
                else:
                    texto_img_classificada = f"Sem Tumor {probabilidade:.2f}%"
                    cor = cor_nao
                    # print(f"Diagnóstico: Sem Tumor (Probabilidade de ser tumor: {probabilidade:.2f}%)")

                # Adicionando texto abaixo da imagem
                fonte = cv2.FONT_HERSHEY_SIMPLEX
                fonte_scala = 0.6
                fonte_peso = 2
                text_size, _ = cv2.getTextSize(texto_img_classificada, fonte, fonte_scala, fonte_peso)
                text_x = c * img_w + (img_w - text_size[0]) // 2  # Centralização do texto
                text_y = r * (img_h + texto_h) + img_h + 25 # Posição do texto
                cv2.putText(mosaico, texto_img_classificada, (text_x, text_y), fonte, fonte_scala, cor, fonte_peso)

                imagem_index += 1

    plt.figure(figsize=(10, 10))
    # Conversão para escala RGB
    plt.imshow(cv2.cvtColor(mosaico, cv2.COLOR_BGR2RGB))
    plt.title(titulo)
    plt.axis('off')
    plt.show()

path_teste_sem_tumor = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte'
path_teste_com_tumor = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte'
arquivos_com_tumor = []
arquivos_sem_tumor = []
valid_extensions = ['.png', '.jpg', '.jpeg'] # Extensões válidas

def listar_dir(path_pasta):
  arquivos = []
  for nome_arquivo in os.listdir(path_pasta):
      # Extensão
      ext = os.path.splitext(nome_arquivo)[1].lower()

      # Verifica se a extensao do arquivo está na lista de extensões validas
      if ext in valid_extensions:
          path_completo = os.path.join(path_pasta, nome_arquivo)
          arquivos.append(path_completo)

  return arquivos

arquivos_sem_tumor = listar_dir(path_teste_sem_tumor)
arquivos_com_tumor = listar_dir(path_teste_com_tumor)

# Cria mosaico e classifica imagens de teste
criar_mosaico('Mosaico de Classificação - Sem tumor',(8,51,162),(64, 145,108),arquivos_sem_tumor, modelo, rows=4, cols=4)
criar_mosaico('Mosaico de Classificação - Com tumor',(64, 145,108),(8,51,162),arquivos_com_tumor, modelo, rows=4, cols=4)
# Out:
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0268.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0266.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0276.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0273.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0264.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0278.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0267.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0265.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0263.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0270.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0274.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0275.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0269.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0271.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0272.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0277.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0054.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0056.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
def classificacao(titulo, com_tumor, sem_tumor, arquivos, modelo):
    """
    Cria um mosaico com imagens classificadas e seus respectivos resulktados.
    """
    imagens = []
    # Classificação das imagens de RM
    erro = 0
    for arquivo in arquivos:
        img = cv2.imread(arquivo)
        img = cv2.resize(img, (largura, altura))
        imagens.append(img)
        print(f"\Classificando imagem {titulo}: {arquivo}")
        # Normaliza imagem e realiza predicao
        img_to_predict = cv2.imread(arquivo)
        img_to_predict = cv2.resize(img_to_predict, (largura, altura))
        img_to_predict = cv2.cvtColor(img_to_predict, cv2.COLOR_BGR2RGB)
        img_to_predict = normalize(img_to_predict, axis=1)
        img_to_predict = img_to_predict.reshape(1, largura, altura, 3)
        predicao = modelo.predict(img_to_predict)
        probabilidade = predicao[0][0] * 100
        # Presença de tunmor: precisao acima de 50%
        if predicao[0][0] > 0.5:
            texto_img_classificada = f"Com Tumor: {probabilidade:.2f}%"
            if com_tumor == True:
                erro += 1
                print(arquivo)
            print(f"Diagnóstico: Tumor Detectado (Probabilidade: {probabilidade:.2f}%)")
        else:
            texto_img_classificada = f"Sem Tumor {probabilidade:.2f}%"
            print(f"Diagnóstico: Sem Tumor (Probabilidade de ser tumor: {probabilidade:.2f}%)")
            if sem_tumor == True:
                erro += 1
                print(arquivo)
    return erro

path_teste_sem_tumor_todos = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor'
path_teste_com_tumor_todos = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor'
arquivos_com_tumor_todos = []
arquivos_sem_tumor_todos = []
valid_extensions = ['.png', '.jpg', '.jpeg'] # Extensões válidas

arquivos_sem_tumor_todos = listar_dir(path_teste_sem_tumor_todos)
arquivos_com_tumor_todos = listar_dir(path_teste_com_tumor_todos)

# Cria mosaico e classifica imagens de teste
erros_sem_tumor = classificacao('sem tumor',True,False,arquivos_sem_tumor_todos, modelo) # retorna falsos positivos
erros_com_tumor = classificacao('Mosaico de Classificação - Com tumor',False,True,arquivos_com_tumor_todos, modelo)  # retorna falsos negativos

print(f"Erros sem tumor: {erros_sem_tumor}")
print(f"Erros com tumor: {erros_com_tumor}")

fp = erros_sem_tumor
fn = erros_com_tumor
tp = 300 - erros_sem_tumor
tn = 300 - erros_com_tumor
# Out:
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0029.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.48%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0051.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.94%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.23%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0053.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.30%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 37.71%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0027.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.92%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 24.85%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0056.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.00%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0020.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 69.19%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0024.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.94%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0042.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.99%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0041.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.67%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0000.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.74%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 23.36%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 24.90%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 15.92%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0030.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0030.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 59.66%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 32.44%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0044.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0044.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 22.20%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0047.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.99%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.93%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0040.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0031.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 49.76%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0055.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0050.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 33.14%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0032.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0032.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 70.73%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0034.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 48.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0037.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.28%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0036.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 32.88%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0018.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.61%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0045.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0045.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 70.76%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0054.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0054.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 70.59%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0035.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.48%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.34%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0048.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.68%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0025.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.27%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.45%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0043.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0043.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.66%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0052.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.48%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0039.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0039.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.76%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0059.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0059.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 50.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0038.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.75%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.94%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.47%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0013.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0003.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0049.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 42.69%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0046.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.82%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.16%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0021.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.20%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0033.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 25.83%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0058.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.96%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0008.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 60.24%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0026.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 15.95%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0071.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0071.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 59.36%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0067.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0067.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 69.27%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 33.06%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0065.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 37.57%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0068.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 23.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.65%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0081.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.12%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0072.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.70%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 22.23%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.98%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0112.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.91%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0123.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0173.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 60.22%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0095.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0095.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 60.81%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0174.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.04%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0087.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0087.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.20%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.60%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0089.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 33.14%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0101.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 55.08%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0076.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.12%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 30.90%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0096.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0096.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.15%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0060.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 34.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0084.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0084.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 54.92%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0163.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0163.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 63.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0099.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0099.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.97%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0183.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0145.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.13%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 26.02%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0168.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.51%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0069.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.31%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0176.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 28.99%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0169.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0169.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 63.02%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.62%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0085.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0126.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 59.28%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0177.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.00%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.89%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0066.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0066.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0182.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0182.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.13%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0082.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 69.84%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 25.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0062.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0062.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.71%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0136.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0162.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0162.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 68.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0079.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 65.58%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0170.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 58.61%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0093.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0093.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.75%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0083.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0083.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.17%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0098.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0098.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 54.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0086.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0086.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.04%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.93%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 17.37%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0117.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 55.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0078.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 30.10%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0119.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 43.80%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 31.31%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0103.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 71.80%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0132.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0124.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0124.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 71.43%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0181.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0181.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.97%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0091.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 29.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0088.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0088.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0158.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.22%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 40.60%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0157.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.83%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 23.65%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0187.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0171.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.54%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.28%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0121.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0121.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.10%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0156.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 70.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.38%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0094.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.10%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0161.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 26.38%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0114.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0114.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.23%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0097.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0116.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0172.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 34.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0184.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 28.37%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0128.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 40.65%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 40.65%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0140.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.00%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0075.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0075.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 54.67%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0125.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.75%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 48.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0149.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0186.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.85%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0063.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.23%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0133.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0133.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 54.06%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0166.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0166.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 68.88%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0080.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0080.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.49%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0146.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0131.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0131.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 55.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0070.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 22.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0092.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0092.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 57.03%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0122.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 43.80%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0073.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 30.10%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0148.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 63.17%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0127.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0127.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 55.47%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 20.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0118.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0118.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0064.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0064.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.52%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 32.25%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0077.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.70%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0107.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.03%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.24%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 33.81%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0090.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.15%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0120.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 61.75%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0061.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 48.19%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0074.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0074.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 65.58%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0289.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0289.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 60.80%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0282.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0282.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 63.17%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0241.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0241.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 56.77%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0274.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.98%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0307.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0291.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0294.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.39%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0278.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 36.71%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0239.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0239.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 51.67%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0255.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0255.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 58.02%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0293.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0293.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 54.15%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0276.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.57%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0238.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.88%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0245.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.78%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0259.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 23.90%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0240.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0240.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 63.24%)
# ...
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 44.07%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0099.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.86%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0109.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0059.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 58.33%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0032.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 52.59%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0038.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 60.46%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.15%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0115.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0041.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 54.96%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0072.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.61%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0072.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0078.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.72%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0078.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0092.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 48.76%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0092.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0073.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 37.60%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0073.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0065.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 50.93%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-piTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 30.92%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-piTr_0005.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 60.83%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0044.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 40.18%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0044.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0052.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.59%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0052.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 49.25%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0057.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0083.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.11%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0083.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0029.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 59.50%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0049.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 49.38%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0049.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.89%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0112.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0086.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 50.70%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0097.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.15%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0097.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0037.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.56%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0037.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0095.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.90%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0095.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0098.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.46%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0098.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.56%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0113.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 44.40%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0055.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0040.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 55.33%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 44.71%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0103.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0060.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 55.34%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 35.90%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0089.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0033.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 63.95%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 66.62%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0096.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.17%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0096.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0077.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 61.93%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0043.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.22%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0043.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 49.36%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0082.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-piTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 56.85%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 42.48%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0102.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0069.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 37.26%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-pi_0069.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-piTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 26.83%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Tr-piTr_0000.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-pi_0056.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 57.19%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-pi_0054.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 65.82%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 39.88%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0001.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.57%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0002.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 46.04%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0000.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-pi_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 50.60%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-pi_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 67.13%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-piTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 58.91%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 61.22%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 62.95%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 37.27%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0003.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 43.86%)
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0002.jpg
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 61.33%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 61.61%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 67.51%)
# \Classificando imagem Mosaico de Classificação - Com tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/Te-meTr_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Tumor Detectado (Probabilidade: 58.06%)
# Erros sem tumor: 114
# Erros com tumor: 167
