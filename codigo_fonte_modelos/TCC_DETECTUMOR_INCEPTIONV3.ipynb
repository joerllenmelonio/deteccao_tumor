# %%
# !nvidia-smi
# Out:
# Sun Jul 27 20:40:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   79C    P0             48W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import warnings
import cv2
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import normalize
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import Binarizer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from tensorflow.keras import layers
from tensorflow.keras.optimizers import SGD
import time

# %%
from google.colab import drive
drive.mount('/content/driv')
# Out:
# Mounted at /content/driv

# %%
timeinicial= time.time()
path ='/content/driv/MyDrive/deteccao_tumores/dataset_cerebros/nao'
path2 ='/content/driv/MyDrive/deteccao_tumores/dataset_cerebros/sim'
arquivos=[os.path.join(path,f) for f in sorted(os.listdir(path))]
arquivos2=[os.path.join(path2,i) for i in sorted(os.listdir(path2))]


largura, altura=299,299
dataset= [] #informações sobre os pixels
label = [] #tipo de classe

for caminho in arquivos:

  imagem= cv2.imread(caminho)
  imagem = cv2.resize(imagem,(largura, altura)) #redimencionando todas as imagens
  #imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY) #transformando as imagens para escala de cinza
  #cv2_imshow(imagem)

  dataset.append(np.array(imagem))
  label.append(0)# adiciona a classe não tem tumor


for caminho2 in arquivos2:

  imagem= cv2.imread(caminho2)
  imagem = cv2.resize(imagem,(largura, altura))#redimencionando todas as imagens
  #imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY) #transformando as imagens para escala de cinza
  #cv2_imshow(imagem)

  dataset.append(np.array(imagem))
  label.append(1)# adiciona classe com tumor


dataset=np.array(dataset)# informação dos pixels
label=np.array(label) # informação das classe
timefinal= time.time()
print(f"duração: {timefinal-timeinicial} segundos")
# Out:
# duração: 17.453778743743896 segundos

# %%
from sklearn.model_selection import train_test_split
# Base de treinamento e teste
x_train, x_test, y_train, y_test=train_test_split(dataset, label, test_size=0.2, random_state=0, shuffle= True)
x_train=normalize(x_train,axis=1)
x_test=normalize(x_test,axis=1)

# %%
# Modelo InceptionV3

base_model =  tf.keras.applications.InceptionV3(include_top= False, weights='imagenet', input_shape=(299, 299, 3), name="inceptionv3")
base_model.trainable = False  # Transfer learning: congela base

# adiciona camada para output
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dropout(0.3)(x)
output = Dense(1, activation='sigmoid')(x)
model = tf.keras.Model(inputs=base_model.input, outputs=output)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 149, 149,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 149, 149,  │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 149, 149,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 147, 147,  │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │         96 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 147, 147,  │     18,432 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │        192 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 73, 73,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 73, 73,    │      5,120 │ max_pooling2d[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 73, 73,    │        240 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 73, 73,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 71, 71,    │    138,240 │ activation_3[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 71, 71,    │        576 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 71, 71,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 35, 35,    │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 35, 35,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 35, 35,    │      9,216 │ max_pooling2d_1[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 35, 35,    │     55,296 │ activation_8[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 35, 35,    │          0 │ max_pooling2d_1[… │
# │ (AveragePooling2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 35, 35,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 35, 35,    │     76,800 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_9[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 35, 35,    │      6,144 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │         96 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed0              │ (None, 35, 35,    │          0 │ activation_5[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 35, 35,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 35, 35,    │     12,288 │ mixed0[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_15[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 35, 35,    │          0 │ mixed0[0][0]      │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 35, 35,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 35, 35,    │     76,800 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_16[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 35, 35,    │     16,384 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed1              │ (None, 35, 35,    │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_14[0]… │
# │                     │                   │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 35, 35,    │     13,824 │ mixed1[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_22[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 35, 35,    │          0 │ mixed1[0][0]      │
# │ (AveragePooling2D)  │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 35, 35,    │     76,800 │ activation_20[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_23[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 35, 35,    │     18,432 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed2              │ (None, 35, 35,    │          0 │ activation_19[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_21[0]… │
# │                     │                   │            │ activation_24[0]… │
# │                     │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed2[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_27[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 17, 17,    │    995,328 │ mixed2[0][0]      │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 17, 17,    │     82,944 │ activation_28[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │      1,152 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        288 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 17, 17,    │          0 │ mixed2[0][0]      │
# │ (MaxPooling2D)      │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed3              │ (None, 17, 17,    │          0 │ activation_26[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_29[0]… │
# │                     │                   │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 17, 17,    │     98,304 │ mixed3[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_34[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 17, 17,    │     98,304 │ mixed3[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_35[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_31[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_36[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 17, 17,    │          0 │ mixed3[0][0]      │
# │ (AveragePooling2D)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed3[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 17, 17,    │    172,032 │ activation_32[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 17, 17,    │    172,032 │ activation_37[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 17, 17,    │    147,456 │ average_pooling2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed4              │ (None, 17, 17,    │          0 │ activation_30[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_33[0]… │
# │                     │                   │            │ activation_38[0]… │
# │                     │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed4[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_44[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed4[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_45[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_41[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_46[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 17, 17,    │          0 │ mixed4[0][0]      │
# │ (AveragePooling2D)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed4[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_42[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_47[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 17, 17,    │    147,456 │ average_pooling2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed5              │ (None, 17, 17,    │          0 │ activation_40[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_43[0]… │
# │                     │                   │            │ activation_48[0]… │
# │                     │                   │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None,
0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_8 │ (None, 8, 8,      │          0 │ mixed9[0][0]      │
# │ (AveragePooling2D)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 8, 8, 320) │    655,360 │ mixed9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 8, 8, 192) │    393,216 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 320) │        960 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 192) │        576 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 8, 8, 320) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_1            │ (None, 8, 8, 768) │          0 │ activation_87[0]… │
# │ (Concatenate)       │                   │            │ activation_88[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 8, 8, 768) │          0 │ activation_91[0]… │
# │ (Concatenate)       │                   │            │ activation_92[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed10             │ (None, 8, 8,      │          0 │ activation_85[0]… │
# │ (Concatenate)       │ 2048)             │            │ mixed9_1[0][0],   │
# │                     │                   │            │ concatenate_1[0]… │
# │                     │                   │            │ activation_93[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ mixed10[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,327,585 (85.17 MB)
#  Trainable params: 524,801 (2.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
tempo_inicial=time.time()
# adam = keras.optimizers.Adam(learning_rate=0.01)
# taxa de aprendizado padrão da SGD: 0.01
# otimizador SGD produz maior acurária caso comparado ao Adam
# treinar apenas camadas adicionadas
model.compile(loss=tf.keras.losses.BinaryCrossentropy(),optimizer=keras.optimizers.SGD(learning_rate=0.01),metrics=['accuracy'])
history=model.fit(x_train,y_train,batch_size=16,epochs=50, validation_data=(x_test,y_test)) #batchsize siginifica que vamos enviar 16 em 16 imagens para a rede neural, sem misturar as imagens enviando com a ordem que está n
tempo_final=time.time()

tempo_final-tempo_inicial
# Out:
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 44s 253ms/step - accuracy: 0.7242 - loss: 0.5509 - val_accuracy: 0.8736 - val_loss: 0.3564
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8730 - loss: 0.3424 - val_accuracy: 0.9126 - val_loss: 0.3015
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8984 - loss: 0.2940 - val_accuracy: 0.9149 - val_loss: 0.2584
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9130 - loss: 0.2482 - val_accuracy: 0.9195 - val_loss: 0.2417
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9208 - loss: 0.2035 - val_accuracy: 0.9333 - val_loss: 0.2288
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9265 - loss: 0.2075 - val_accuracy: 0.9218 - val_loss: 0.2268
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9328 - loss: 0.1824 - val_accuracy: 0.9264 - val_loss: 0.2050
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9359 - loss: 0.1772 - val_accuracy: 0.9402 - val_loss: 0.1941
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9484 - loss: 0.1591 - val_accuracy: 0.9356 - val_loss: 0.1929
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9640 - loss: 0.1368 - val_accuracy: 0.9448 - val_loss: 0.1783
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9570 - loss: 0.1365 - val_accuracy: 0.9011 - val_loss: 0.2716
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9538 - loss: 0.1454 - val_accuracy: 0.9494 - val_loss: 0.1705
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9690 - loss: 0.1177 - val_accuracy: 0.9471 - val_loss: 0.1663
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9528 - loss: 0.1263 - val_accuracy: 0.9471 - val_loss: 0.1651
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9698 - loss: 0.1130 - val_accuracy: 0.9517 - val_loss: 0.1612
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.
50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9927 - loss: 0.0316 - val_accuracy: 0.9655 - val_loss: 0.1067
# Epoch 48/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9975 - loss: 0.0237 - val_accuracy: 0.9586 - val_loss: 0.1098
# Epoch 49/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9904 - loss: 0.0340 - val_accuracy: 0.9609 - val_loss: 0.1058
# Epoch 50/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9941 - loss: 0.0334 - val_accuracy: 0.9609 - val_loss: 0.1070
# 456.42703437805176

# %%
# realizando fine tuning
tempo_inicial=time.time()
base_model.trainable = True # descongela modelo
model.summary()

# inicia fine tune a partir da camada 100
fine_tune_at = 200

# congela todas as camadas até chegar na camada de `fine_tune_at`
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

model.compile(loss=tf.keras.losses.BinaryCrossentropy(),optimizer=keras.optimizers.SGD(learning_rate=0.00001),metrics=['accuracy'])
history=model.fit(x_train,y_train,batch_size=16,epochs=120, initial_epoch=len(history.epoch), validation_data=(x_test,y_test)) #batchsize siginifica que vamos enviar 16 em 16 imagens para a rede neural, sem misturar as imagens enviando com a ordem que está n
tempo_final=time.time()

tempo_final-tempo_inicial
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 299, 299,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 149, 149,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 149, 149,  │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 149, 149,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 147, 147,  │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │         96 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 147, 147,  │     18,432 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 147, 147,  │        192 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 147, 147,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 73, 73,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 73, 73,    │      5,120 │ max_pooling2d[0]… │
# │                     │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 73, 73,    │        240 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 73, 73,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 71, 71,    │    138,240 │ activation_3[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 71, 71,    │        576 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 71, 71,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 35, 35,    │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 35, 35,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 35, 35,    │      9,216 │ max_pooling2d_1[… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 35, 35,    │     55,296 │ activation_8[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 35, 35,    │          0 │ max_pooling2d_1[… │
# │ (AveragePooling2D)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 35, 35,    │     12,288 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 35, 35,    │     76,800 │ activation_6[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_9[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 35, 35,    │      6,144 │ average_pooling2… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │         96 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed0              │ (None, 35, 35,    │          0 │ activation_5[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 35, 35,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 35, 35,    │     12,288 │ mixed0[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_15[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 35, 35,    │          0 │ mixed0[0][0]      │
# │ (AveragePooling2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 35, 35,    │     16,384 │ mixed0[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 35, 35,    │     76,800 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_16[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 35, 35,    │     16,384 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed1              │ (None, 35, 35,    │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_14[0]… │
# │                     │                   │            │ activation_17[0]… │
# │                     │                   │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 35, 35,    │     13,824 │ mixed1[0][0]      │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_22[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        144 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 35, 35,    │          0 │ mixed1[0][0]      │
# │ (AveragePooling2D)  │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed1[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 35, 35,    │     76,800 │ activation_20[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 35, 35,    │     82,944 │ activation_23[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 35, 35,    │     18,432 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed2              │ (None, 35, 35,    │          0 │ activation_19[0]… │
# │ (Concatenate)       │ 288)              │            │ activation_21[0]… │
# │                     │                   │            │ activation_24[0]… │
# │                     │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 35, 35,    │     18,432 │ mixed2[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 35, 35,    │     55,296 │ activation_27[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 35, 35,    │        288 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 35, 35,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 17, 17,    │    995,328 │ mixed2[0][0]      │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 17, 17,    │     82,944 │ activation_28[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │      1,152 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        288 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 17, 17,    │          0 │ mixed2[0][0]      │
# │ (MaxPooling2D)      │ 288)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed3              │ (None, 17, 17,    │          0 │ activation_26[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_29[0]… │
# │                     │                   │            │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 17, 17,    │     98,304 │ mixed3[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_34[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 17, 17,    │     98,304 │ mixed3[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_35[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_31[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 17, 17,    │    114,688 │ activation_36[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        384 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_3 │ (None, 17, 17,    │          0 │ mixed3[0][0]      │
# │ (AveragePooling2D)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed3[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 17, 17,    │    172,032 │ activation_32[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 17, 17,    │    172,032 │ activation_37[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 17, 17,    │    147,456 │ average_pooling2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed4              │ (None, 17, 17,    │          0 │ activation_30[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_33[0]… │
# │                     │                   │            │ activation_38[0]… │
# │                     │                   │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed4[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_44[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed4[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_45[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_41[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_46[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_4 │ (None, 17, 17,    │          0 │ mixed4[0][0]      │
# │ (AveragePooling2D)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed4[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_42[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_47[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 17, 17,    │    147,456 │ average_pooling2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed5              │ (None, 17, 17,    │          0 │ activation_40[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_43[0]… │
# │                     │                   │            │ activation_48[0]… │
# │                     │                   │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed5[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_54[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 17, 17,    │    122,880 │ mixed5[0][0]      │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_55[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_56[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_51[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 17, 17,    │    179,200 │ activation_56[0]… │
# │                     │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        480 │ conv2d_57[0][0]   │
# │ (BatchNormalizatio… │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 160)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_5 │ (None, 17, 17,    │          0 │ mixed5[0][0]      │
# │ (AveragePooling2D)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed5[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_52[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 17, 17,    │    215,040 │ activation_57[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 17, 17,    │    147,456 │ average_pooling2… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_58[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed6              │ (None, 17, 17,    │          0 │ activation_50[0]… │
# │ (Concatenate)       │ 768)              │            │ activation_53[0]… │
# │                     │                   │            │ activation_58[0]… │
# │                     │                   │            │ activation_59[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 17, 17,    │    147,456 │ mixed6[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_64[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_64       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 17, 17,    │    258,048 │ activation_64[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 17, 17,    │        576 │ conv2d_65[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_65       │ (None, 17, 17,    │          0 │ batch_normalizat… │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_86       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 8, 8, 384) │    442,368 │ activation_86[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 8, 8, 384) │    442,368 │ activation_86[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 8, 8, 384) │    442,368 │ activation_90[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 8, 8, 384) │    442,368 │ activation_90[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_8 │ (None, 8, 8,      │          0 │ mixed9[0][0]      │
# │ (AveragePooling2D)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 8, 8, 320) │    655,360 │ mixed9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 384) │      1,152 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 8, 8, 192) │    393,216 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 320) │        960 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_87       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_88       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 8, 8, 384) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 192) │        576 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_85       │ (None, 8, 8, 320) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed9_1            │ (None, 8, 8, 768) │          0 │ activation_87[0]… │
# │ (Concatenate)       │                   │            │ activation_88[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 8, 8, 768) │          0 │ activation_91[0]… │
# │ (Concatenate)       │                   │            │ activation_92[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mixed10             │ (None, 8, 8,      │          0 │ activation_85[0]… │
# │ (Concatenate)       │ 2048)             │            │ mixed9_1[0][0],   │
# │                     │                   │            │ concatenate_1[0]… │
# │                     │                   │            │ activation_93[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ mixed10[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    524,544 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,327,587 (85.17 MB)
#  Trainable params: 22,293,153 (85.04 MB)
#  Non-trainable params: 34,432 (134.50 KB)
#  Optimizer params: 2 (12.00 B)
# Epoch 51/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 55s 297ms/step - accuracy: 0.8836 - loss: 0.2726 - val_accuracy: 0.9402 - val_loss: 0.1613
# Epoch 52/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 13s 114ms/step - accuracy: 0.8866 - loss: 0.2951 - val_accuracy: 0.9218 - val_loss: 0.1993
# Epoch 53/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.8724 - loss: 0.2872 - val_accuracy: 0.9103 - val_loss: 0.2197
# Epoch 54/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.8775 - loss: 0.3068 - val_accuracy: 0.9080 - val_loss: 0.2244
# Epoch 55/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.8939 - loss: 0.2701 - val_accuracy: 0.9057 - val_loss: 0.2229
# Epoch 56/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.8791 - loss: 0.2873 - val_accuracy: 0.9057 - val_loss: 0.2187
# Epoch 57/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.8954 - loss: 0.2750 - val_accuracy: 0.9103 - val_loss: 0.2144
# Epoch 58/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - accuracy: 0.8962 - loss: 0.2591 - val_accuracy: 0.9126 - val_loss: 0.2099
# Epoch 59/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - accuracy: 0.8988 - loss: 0.2431 - val_accuracy: 0.9218 - val_loss: 0.2054
# Epoch 60/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.8738 - loss: 0.2982 - val_accuracy: 0.9264 - val_loss: 0.2015
# Epoch 61/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9227 - loss: 0.2158 - val_accuracy: 0.9264 - val_loss: 0.1976
# Epoch 62/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9032 - loss: 0.2500 - val_accuracy: 0.9264 - val_loss: 0.1935
# Epoch 63/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.8946 - loss: 0.2786 - val_accuracy: 0.9310 - val_loss: 0.1900
# Epoch 64/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.8974 - loss: 0.2541 - val_accuracy: 0.9310 - val_loss: 0.1875
# Epoch 65/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - accuracy: 0.9290 - loss: 0.2018 - val_accuracy: 0.9356 - val_loss: 0.1853
# Epoch 66/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - accuracy: 0.9043 - loss: 0.2321 - val_accuracy: 0.9356 - val_loss: 0.1819
# Epoch 67/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.
120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.9446 - loss: 0.1669 - val_accuracy: 0.9586 - val_loss: 0.1342
# Epoch 99/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9486 - loss: 0.1343 - val_accuracy: 0.9609 - val_loss: 0.1331
# Epoch 100/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9426 - loss: 0.1551 - val_accuracy: 0.9586 - val_loss: 0.1321
# Epoch 101/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9617 - loss: 0.1233 - val_accuracy: 0.9586 - val_loss: 0.1317
# Epoch 102/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9555 - loss: 0.1134 - val_accuracy: 0.9586 - val_loss: 0.1310
# Epoch 103/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9427 - loss: 0.1572 - val_accuracy: 0.9586 - val_loss: 0.1301
# Epoch 104/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.9403 - loss: 0.1535 - val_accuracy: 0.9586 - val_loss: 0.1293
# Epoch 105/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9510 - loss: 0.1360 - val_accuracy: 0.9586 - val_loss: 0.1290
# Epoch 106/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9515 - loss: 0.1393 - val_accuracy: 0.9609 - val_loss: 0.1284
# Epoch 107/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9635 - loss: 0.1176 - val_accuracy: 0.9586 - val_loss: 0.1276
# Epoch 108/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9634 - loss: 0.1212 - val_accuracy: 0.9586 - val_loss: 0.1268
# Epoch 109/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9592 - loss: 0.1106 - val_accuracy: 0.9586 - val_loss: 0.1258
# Epoch 110/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9669 - loss: 0.1155 - val_accuracy: 0.9586 - val_loss: 0.1256
# Epoch 111/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.9552 - loss: 0.1265 - val_accuracy: 0.9586 - val_loss: 0.1251
# Epoch 112/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9507 - loss: 0.1184 - val_accuracy: 0.9586 - val_loss: 0.1244
# Epoch 113/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9554 - loss: 0.1296 - val_accuracy: 0.9609 - val_loss: 0.1238
# Epoch 114/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 111ms/step - accuracy: 0.9559 - loss: 0.1286 - val_accuracy: 0.9609 - val_loss: 0.1231
# Epoch 115/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9529 - loss: 0.1289 - val_accuracy: 0.9586 - val_loss: 0.1225
# Epoch 116/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9529 - loss: 0.1317 - val_accuracy: 0.9609 - val_loss: 0.1218
# Epoch 117/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9640 - loss: 0.1147 - val_accuracy: 0.9609 - val_loss: 0.1214
# Epoch 118/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9519 - loss: 0.1241 - val_accuracy: 0.9632 - val_loss: 0.1210
# Epoch 119/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9656 - loss: 0.1134 - val_accuracy: 0.9609 - val_loss: 0.1207
# Epoch 120/120
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - accuracy: 0.9653 - loss: 0.1043 - val_accuracy: 0.9632 - val_loss: 0.1198
# 903.4906239509583

# %%
print(f"o codigo demorou {int(tempo_final-tempo_inicial)} segundos")
# Out:
# o codigo demorou 903 segundos

# %%
from sklearn.preprocessing import Binarizer
# predição para obter acurácia do modelo
score = model.evaluate(x_test, y_test)
prediction = model.predict(x_test)
#############
binarizer = Binarizer(threshold=0.50).fit(prediction)
binary = binarizer.transform(prediction)
#############
y_test = y_test
y_pred = binary
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 696ms/step - accuracy: 0.9549 - loss: 0.1339
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 12s 507ms/step

# %%
print("Resultados da Classificação = ")
print(classification_report(y_test,y_pred))
# Out:
# Resultados da Classificação =
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       309
#            1       0.95      0.92      0.94       126
#
#     accuracy                           0.96       435
#    macro avg       0.96      0.95      0.95       435
# weighted avg       0.96      0.96      0.96       435

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the loss and accuracy curve
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='melhor época = '+ str(index_loss+1 +start_epoch)
    vc_label='melhor época = '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Perda de Treinamento')
    axes[0].plot(Epochs,vloss,'g',label='Perda de Validação' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Treinamento e validação das perdas')
    axes[0].set_xlabel('Épocas')
    axes[0].set_ylabel('Perda')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Acurácia de Treinamento')
    axes[1].plot (Epochs,vacc,'g',label= 'Acurácia de Validação')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Treinamento e validação da acurácia')
    axes[1].set_xlabel('Épocas')
    axes[1].set_ylabel('Acurácia')
    axes[1].legend()
    plt.tight_layout

    plt.show()

tr_plot(history,0)
plt.savefig('history.png')
model.save('/content/driv/MyDrive/deteccao_tumores/modelos/modelo_inceptionv3.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
caminho_modelo = '/content/driv/MyDrive/deteccao_tumores/modelos/modelo_inceptionv3.h5'
modelo = tf.keras.models.load_model(caminho_modelo)
largura, altura=299,299
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def criar_mosaico(titulo, cor_sim, cor_nao, arquivos, modelo, rows, cols):
    """
    Cria um mosaico com imagens classificadas e seus respectivos resulktados.
    """
    imagens = []
    for arquivo in arquivos:
        img = cv2.imread(arquivo)
        if img is not None:
            img = cv2.resize(img, (largura, altura))
            imagens.append(img)
        else:
            print(f"Nao foi possivel carregar imagem {arquivo}")

    if not imagens:
        print("Nenhuma imagem carregada.")
        return

    # Define tamanho do mosaico
    img_h, img_w, _ = imagens[0].shape
    texto_h = 40  # Espaço para texto
    mosaico_h = (img_h + texto_h) * rows
    mosaico_w = img_w * cols
    mosaico = np.zeros((mosaico_h, mosaico_w, 3), dtype=np.uint8)
    mosaico.fill(255)


    # Classificação das imagens de RM
    imagem_index = 0
    for r in range(rows):
        for c in range(cols):
            if imagem_index < len(imagens):
                # Place the image
                mosaico[r * (img_h + texto_h):r * (img_h + texto_h) + img_h, c * img_w:(c + 1) * img_w] = imagens[imagem_index]

                # Classificação
                print(f"\Classificando imagem: {arquivos[imagem_index]}")
                # Normaliza imagem e realiza predicao
                img_to_predict = cv2.imread(arquivos[imagem_index])
                img_to_predict = cv2.resize(img_to_predict, (largura, altura))
                img_to_predict = cv2.cvtColor(img_to_predict, cv2.COLOR_BGR2RGB)
                img_to_predict = normalize(img_to_predict, axis=1)
                img_to_predict = img_to_predict.reshape(1, largura, altura, 3)
                predicao = modelo.predict(img_to_predict)
                probabilidade = predicao[0][0] * 100
                # Presença de tunmor: precisao acima de 50%
                if predicao[0][0] > 0.5:
                    texto_img_classificada = f"Com Tumor: {probabilidade:.2f}%"
                    cor = cor_sim # Cor definida para respostas certas/erradas
                    # print(f"Diagnóstico: Tumor Detectado (Probabilidade: {probabilidade:.2f}%)")
                else:
                    texto_img_classificada = f"Sem Tumor {probabilidade:.2f}%"
                    cor = cor_nao
                    # print(f"Diagnóstico: Sem Tumor (Probabilidade de ser tumor: {probabilidade:.2f}%)")

                # Adicionando texto abaixo da imagem
                fonte = cv2.FONT_HERSHEY_SIMPLEX
                fonte_scala = 0.6
                fonte_peso = 2
                text_size, _ = cv2.getTextSize(texto_img_classificada, fonte, fonte_scala, fonte_peso)
                text_x = c * img_w + (img_w - text_size[0]) // 2  # Centralização do texto
                text_y = r * (img_h + texto_h) + img_h + 25 # Posição do texto
                cv2.putText(mosaico, texto_img_classificada, (text_x, text_y), fonte, fonte_scala, cor, fonte_peso)

                imagem_index += 1

    plt.figure(figsize=(10, 10))
    # Conversão para escala RGB
    plt.imshow(cv2.cvtColor(mosaico, cv2.COLOR_BGR2RGB))
    plt.title(titulo)
    plt.axis('off')
    plt.show()

path_teste_sem_tumor = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte'
path_teste_com_tumor = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte'
arquivos_com_tumor = []
arquivos_sem_tumor = []
valid_extensions = ['.png', '.jpg', '.jpeg'] # Extensões válidas

def listar_dir(path_pasta):
  arquivos = []
  for nome_arquivo in os.listdir(path_pasta):
      # Extensão
      ext = os.path.splitext(nome_arquivo)[1].lower()

      # Verifica se a extensao do arquivo está na lista de extensões validas
      if ext in valid_extensions:
          path_completo = os.path.join(path_pasta, nome_arquivo)
          arquivos.append(path_completo)

  return arquivos

arquivos_sem_tumor = listar_dir(path_teste_sem_tumor)
arquivos_com_tumor = listar_dir(path_teste_com_tumor)

# Cria mosaico e classifica imagens de teste
criar_mosaico('Mosaico de Classificação - Sem tumor',(8,51,162),(64, 145,108),arquivos_sem_tumor, modelo, rows=4, cols=4)
criar_mosaico('Mosaico de Classificação - Com tumor',(64, 145,108),(8,51,162),arquivos_com_tumor, modelo, rows=4, cols=4)
# Out:
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0268.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0266.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0276.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0273.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0264.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0278.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0267.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0265.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0263.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0270.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0274.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0275.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0269.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0271.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0272.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/recorte/Cópia de Te-no_0277.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0054.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-meTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0056.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-pi_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# \Classificando imagem: /content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor/recorte/Cópia de Te-piTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
def classificacao(titulo, com_tumor, sem_tumor, arquivos, modelo):
    """
    Cria um mosaico com imagens classificadas e seus respectivos resulktados.
    """
    imagens = []
    # Classificação das imagens de RM
    erro = 0
    for arquivo in arquivos:
        img = cv2.imread(arquivo)
        img = cv2.resize(img, (largura, altura))
        imagens.append(img)
        print(f"\Classificando imagem {titulo}: {arquivo}")
        # Normaliza imagem e realiza predicao
        img_to_predict = cv2.imread(arquivo)
        img_to_predict = cv2.resize(img_to_predict, (largura, altura))
        img_to_predict = cv2.cvtColor(img_to_predict, cv2.COLOR_BGR2RGB)
        img_to_predict = normalize(img_to_predict, axis=1)
        img_to_predict = img_to_predict.reshape(1, largura, altura, 3)
        predicao = modelo.predict(img_to_predict)
        probabilidade = predicao[0][0] * 100
        # Presença de tunmor: precisao acima de 50%
        if predicao[0][0] > 0.5:
            texto_img_classificada = f"Com Tumor: {probabilidade:.2f}%"
            if com_tumor == True:
                erro += 1
                print(arquivo)
            print(f"Diagnóstico: Tumor Detectado (Probabilidade: {probabilidade:.2f}%)")
        else:
            texto_img_classificada = f"Sem Tumor {probabilidade:.2f}%"
            print(f"Diagnóstico: Sem Tumor (Probabilidade de ser tumor: {probabilidade:.2f}%)")
            if sem_tumor == True:
                erro += 1
                print(arquivo)
    return erro

path_teste_sem_tumor_todos = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor'
path_teste_com_tumor_todos = '/content/driv/MyDrive/deteccao_tumores/dataset_teste/com_tumor'
arquivos_com_tumor_todos = []
arquivos_sem_tumor_todos = []
valid_extensions = ['.png', '.jpg', '.jpeg'] # Extensões válidas

arquivos_sem_tumor_todos = listar_dir(path_teste_sem_tumor_todos)
arquivos_com_tumor_todos = listar_dir(path_teste_com_tumor_todos)

# Cria mosaico e classifica imagens de teste
erros_sem_tumor = classificacao('sem tumor',True,False,arquivos_sem_tumor_todos, modelo) # retorna falsos positivos
erros_com_tumor = classificacao('Mosaico de Classificação - Com tumor',False,True,arquivos_com_tumor_todos, modelo)  # retorna falsos negativos

print(f"Erros sem tumor: {erros_sem_tumor}")
print(f"Erros com tumor: {erros_com_tumor}")

fp = erros_sem_tumor
fn = erros_com_tumor
tp = 300 - erros_sem_tumor
tn = 300 - erros_com_tumor
# Out:
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0029.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0051.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 4.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 7.10%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0053.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0053.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 58.52%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0027.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.34%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.50%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0056.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 8.91%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0020.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.68%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0024.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 4.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0042.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0009.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.72%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0041.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0041.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.19%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0000.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0000.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 86.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 11.03%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.12%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0030.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.50%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.38%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0044.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.63%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.51%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0047.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 28.70%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0014.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.31%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 8.44%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0040.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 47.61%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0031.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 6.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0050.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.75%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0032.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.57%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0034.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 21.17%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0037.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.37%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0036.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.05%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 16.61%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0045.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 10.93%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0054.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0054.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 75.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0035.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.85%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0023.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.55%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0048.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 49.43%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0025.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.33%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0019.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 44.48%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0057.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0043.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0043.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 66.52%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0052.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0039.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.12%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0059.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0059.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 94.65%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0038.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 4.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.04%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0013.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0013.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.31%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 9.95%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0049.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 38.36%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0046.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.38%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.66%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0021.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0021.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 97.73%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0033.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.07%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0058.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0058.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 96.34%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-noTr_0008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 45.18%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0026.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 3.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0071.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0071.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 73.96%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0067.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.80%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0106.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 80.18%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0065.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.48%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0068.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0068.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 92.43%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 13.20%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0081.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0081.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 98.02%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0072.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0072.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 81.85%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.23%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.87%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.74%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0112.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 79.19%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.69%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 33.88%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0095.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 4.27%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0174.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 62.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0087.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0087.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 97.15%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 8.77%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 4.60%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.47%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.04%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0076.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0076.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 98.02%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.95%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.98%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 41.64%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.95%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0096.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 23.44%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.01%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0060.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.41%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0084.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0084.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 59.46%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0163.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 13.57%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0099.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0099.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 77.85%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0183.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.00%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.56%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.24%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.59%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0069.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.61%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0176.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 3.04%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0169.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 5.53%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.81%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0085.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0085.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 64.99%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 31.97%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0177.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 3.35%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.32%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0066.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 14.21%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0182.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.56%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0082.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 79.63%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.09%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0062.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0062.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 71.37%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 19.69%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0162.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.42%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 40.24%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.38%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0093.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 27.98%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.26%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 8.92%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0083.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 18.12%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0098.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0098.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 53.81%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0086.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0086.jpg
# Diagnóstico: Tumor Detectado (Probabilidade: 86.41%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 1.79%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 2.74%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_0117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Diagnóstico: Sem Tumor (Probabilidade de ser tumor: 0.97%)
# \Classificando imagem sem tumor: /content/driv/MyDrive/deteccao_tumores/dataset_teste/sem_tumor/Tr-no_